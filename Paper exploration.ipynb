# %%
from os import listdir
import pandas as pd 
import re
from collections import Counter
from nltk import tokenize
import matplotlib.pyplot as plt
import seaborn as sns
from stylometry.stylometry.extract import *
import spacy
import en_core_web_sm
from utilities import *

# ML
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.feature_selection import SelectFromModel

# %%
def load_data_to_pandas():
    data = {}
    for file_name in listdir('data/green roofs/'):
        text = open('data/green roofs/'+file_name, "r").read()
        data[file_name.replace('.txt', '')] = text
    data_frame = pd.DataFrame(data.items(), columns=['Source', 'Paper'])
    return data_frame
df = load_data_to_pandas()

# %%
df
# Out:
#                                                Source  \
# 0               Razzaghmanesh, Beecham, Salemi (2016)
# 1                    Liu, Feng, Chen, Wei, Deo (2019)
# 2          Soulis, Ntoulas, Nektarios & Kargas (2017)
# 3          Morakinyo, Dahanayake, Ng, Lun Chow (2017)
# 4   Herrera-Gomez, Quevedo-Nolasco, Perez-Urrestar...
# 5                               Tam, Wang, Le (2016 )
# 6                              Rasul & Arutla (2020)
# 7                Chaudhary, Sandall, Lazarski (2019 )
# 8                              Vijayaraghavan (2016)
# 9                                   Lee & Jim (2018)
# 10           Vijayaraghavan, Kumar Reddy, Yun (2019 )
# 11  Catalano, Marceno, Armando Laudicina, Guarino ...
# 12                             Chen, Kang, Lin (2018)
# 13       Mahdiyar, Tabatabaee, Abdullah, Marto (2018)
# 14   Karachaliou, Santamouris, Helli Pangalou (2015)
# 15                 Grunwald, Heusinger & Weber (2017)
# 16                    Brudermann & Sangkakool (2016)
# 17                       Shafique, Kim & Rafiq (2018)
# 18       Agra, Klein, Vasl, Kadas & Blaustein (2017 )
# 19  Reyes, Bustamante, Gironas, Pasten, Rojas, Sua...
# 20         Coma, Perez, Sole, Castell & Cabeza (2016)
# 21  Karteris, Theodoridou, Mallinis, Tsiros, Karte...
# 22  Mahdiyar, Tabatabaee, Nobahar Sadeghifam, Reza...
# 23                            Perini, Rosasco (2016 )
# 24                                       Susca (2019)
# 25           Shafique, Azam, Rafiq, Ateeq, Luo (2020)
#
#                                                 Paper
# 0   Urbanisation growth, climate change and water ...
# 1   Although rapid urbanization warrants a need to...
# 2   Green roofs are emerging as one of the most pr...
# 3   As a consequence of rapid urbanization, many g...
# 4   Numerous studies on climate change predict a g...
# 5   In Hong Kong, high pollution and lack of green...
# 6   Industrialisation, increase in luxury of the p...
# 7   Land-system conversion through urbanization re...
# 8   As a result of rapid economic growth, many cou...
# 9   Compact cities are susceptible to  the double ...
# 10  A vegetative roof implies planting vegetation ...
# 11  Urban sustainability is one of the urgent chal...
# 12  Green roofs can produce many environmental ben...
# 13  Green roof, as a sustainable alternative of th...
# 14  Urban warming is a major threat to urban popul...
# 15  Given the ongoing trend of global urbanization...
# 16  In recent decades and years , improved recogni...
# 17  Climate change and urbanization are the topics...
# 18  Urban ecosystems are expanding globally, and a...
# 19  In the last two decades, there has been substa...
# 20  During the last two decades , the building sec...
# 21  Buildings  and other engineered structures tha...
# 22  Sustainable approaches in construction industr...
# 23  A wide replication of green envelopes can be a...
# 24  In 2007 the majority of the world-wide populat...
# 25  Recently, urbanization is a megatrend around t...

# %%
df['alpha-chars-ratio'] = df['Paper'].apply(alpha_chars_ratio)
df['digit-chars-ratio'] = df['Paper'].apply(digit_chars_ratio)
df['upper-chars-ratio'] = df['Paper'].apply(upper_chars_ratio)
df['white-chars-ratio'] = df['Paper'].apply(white_chars_ratio)
df['number-of-words'] = df['Paper'].apply(total_number_of_words)
df['size-of-vocabulary'] = df['Paper'].apply(size_of_vocabulary)
df['type-token-ratio'] = df['Paper'].apply(lexical_diversity)
df['hapax-legomena'] = df['Paper'].apply(hapax_legomena)
df['hapax-dislegomena'] = df['Paper'].apply(hapax_dislegomena)
df['mean-word-length'] = df['Paper'].apply(mean_word_length)
df['mean-sentence-char-length'] = df['Paper'].apply(average_sentence_char_length)
df['mean-sentence-word-length'] = df['Paper'].apply(average_sentence_word_length)
df['mean-paragraph-length'] = df['Paper'].apply(mean_paragraph_len)
df['exclamation_mark_rate'] = df['Paper'].apply(exclamation_mark_rate)
df['question-mark-rate'] = df['Paper'].apply(question_mark_rate)
df['adverbs-rate'] = df['Paper'].apply(number_of_adverbs)
df['adjectives-rate'] = df['Paper'].apply(number_of_adjectives)
df['nouns-rate'] = df['Paper'].apply(number_of_nouns)
df['prepositions-rate'] = df['Paper'].apply(number_of_prepositions)
df['conjuctions-rate'] = df['Paper'].apply(number_of_conjuctions)
df['verb-rate'] = df['Paper'].apply(number_of_verbs)
df['adjectivs-adverbs-rate'] = df['Paper'].apply(adj_adv)
df['named-entites-count'] = df['Paper'].apply(number_of_ne)

# %%
df
# Out:
#                                                Source  \
# 0               Razzaghmanesh, Beecham, Salemi (2016)
# 1                    Liu, Feng, Chen, Wei, Deo (2019)
# 2          Soulis, Ntoulas, Nektarios & Kargas (2017)
# 3          Morakinyo, Dahanayake, Ng, Lun Chow (2017)
# 4   Herrera-Gomez, Quevedo-Nolasco, Perez-Urrestar...
# 5                               Tam, Wang, Le (2016 )
# 6                              Rasul & Arutla (2020)
# 7                Chaudhary, Sandall, Lazarski (2019 )
# 8                              Vijayaraghavan (2016)
# 9                                   Lee & Jim (2018)
# 10           Vijayaraghavan, Kumar Reddy, Yun (2019 )
# 11  Catalano, Marceno, Armando Laudicina, Guarino ...
# 12                             Chen, Kang, Lin (2018)
# 13       Mahdiyar, Tabatabaee, Abdullah, Marto (2018)
# 14   Karachaliou, Santamouris, Helli Pangalou (2015)
# 15                 Grunwald, Heusinger & Weber (2017)
# 16                    Brudermann & Sangkakool (2016)
# 17                       Shafique, Kim & Rafiq (2018)
# 18       Agra, Klein, Vasl, Kadas & Blaustein (2017 )
# 19  Reyes, Bustamante, Gironas, Pasten, Rojas, Sua...
# 20         Coma, Perez, Sole, Castell & Cabeza (2016)
# 21  Karteris, Theodoridou, Mallinis, Tsiros, Karte...
# 22  Mahdiyar, Tabatabaee, Nobahar Sadeghifam, Reza...
# 23                            Perini, Rosasco (2016 )
# 24                                       Susca (2019)
# 25           Shafique, Azam, Rafiq, Ateeq, Luo (2020)
#
#                                                 Paper  alpha-chars-ratio  \
# 0   Urbanisation growth, climate change and water ...           0.774358
# 1   Although rapid urbanization warrants a need to...           0.784761
# 2   Green roofs are emerging as one of the most pr...           0.767360
# 3   As a consequence of rapid urbanization, many g...           0.812384
# 4   Numerous studies on climate change predict a g...           0.800773
# 5   In Hong Kong, high pollution and lack of green...           0.811107
# 6   Industrialisation, increase in luxury of the p...           0.806493
# 7   Land-system conversion through urbanization re...           0.798241
# 8   As a result of rapid economic growth, many cou...           0.821545
# 9   Compact cities are susceptible to  the double ...           0.789193
# 10  A vegetative roof implies planting vegetation ...           0.783622
# 11  Urban sustainability is one of the urgent chal...           0.765551
# 12  Green roofs can produce many environmental ben...           0.797669
# 13  Green roof, as a sustainable alternative of th...           0.772666
# 14  Urban warming is a major threat to urban popul...           0.819983
# 15  Given the ongoing trend of global urbanization...           0.754937
# 16  In recent decades and years , improved recogni...           0.762514
# 17  Climate change and urbanization are the topics...           0.807562
# 18  Urban ecosystems are expanding globally, and a...           0.808911
# 19  In the last two decades, there has been substa...           0.771663
# 20  During the last two decades , the building sec...           0.789191
# 21  Buildings  and other engineered structures tha...           0.816142
# 22  Sustainable approaches in construction industr...           0.778818
# 23  A wide replication of green envelopes can be a...           0.765754
# 24  In 2007 the majority of the world-wide populat...           0.773932
# 25  Recently, urbanization is a megatrend around t...           0.764573
#
#     digit-chars-ratio  upper-chars-ratio  white-chars-ratio  number-of-words  \
# 0            0.033204           0.021086           0.156810              646
# 1            0.026534           0.013045           0.153128             1030
# 2            0.038839           0.018831           0.152413              774
# 3            0.010906           0.008503           0.145841              787
# 4            0.009198           0.010302           0.162620              881
# 5            0.010968           0.011316           0.151114              863
# 6            0.004137           0.012094           0.161680              507
# 7            0.020029           0.017831           0.142648              583
# 8            0.003999           0.007248           0.150962              602
# 9            0.023338           0.025875           0.152461              599
# 10           0.024134           0.023721           0.144802              700
# 11           0.040644           0.023792           0.147212              590
# 12           0.020581           0.011804           0.151483              995
# 13           0.027244           0.021438           0.153863              687
# 14           0.003070           0.007536           0.154898              552
# 15           0.038943           0.021697           0.152712              547
# 16           0.038111           0.019909           0.161263              565
# 17           0.010804           0.009228           0.151699              672
# 18           0.010891           0.010891           0.155446              315
# 19           0.031925           0.018851           0.152630              500
# 20           0.025750           0.011036           0.143463              503
# 21           0.007654           0.006262           0.152896              873
# 22           0.027858           0.017051           0.155379              645
# 23           0.035522           0.020015           0.156604             1411
# 24           0.033261           0.010817           0.145214              533
# 25           0.037359           0.023510           0.149758              463
#
#     size-of-vocabulary  type-token-ratio  hapax-legomena  ...  \
# 0                  295         41.214470             204  ...
# 1                  431         36.696501             292  ...
# 2                  323         36.008448             213  ...
# 3                  375         43.326039             266  ...
# 4                  379         39.275220             261  ...
# 5                  411         43.838384             288  ...
# 6                  238         43.367347             159  ...
# 7                  317         45.643154             229  ...
# 8                  290         45.123726             204  ...
# 9                  303         46.120690             217  ...
# 10                 370         43.047831             285  ...
# 11                 343         48.048452             270  ...
# 12                 385         34.801016             248  ...
# 13                 283         34.988453             194  ...
# 14                 249         42.197452             170  ...
# 15                 274         40.567376             200  ...
# 16                 282         44.100295             208  ...
# 17                 289         40.000000             188  ...
# 18                 188         57.062147             142  ...
# 7                 0.030777             0.012702
# 8                 0.035491             0.002000
# 9                 0.028412             0.014967
# 10                0.026196             0.019183
# 11                0.022800             0.021066
# 12                0.025726             0.011955
# 13                0.030594             0.018535
# 14                0.024002             0.003070
# 15                0.028651             0.021697
# 16                0.033276             0.019056
# 17                0.031510             0.004952
# 18                0.031188             0.005446
# 19                0.027972             0.021283
# 20                0.020091             0.009055
# 21                0.028179             0.005044
# 22                0.030500             0.015850
# 23                0.025954             0.019136
# 24                0.027312             0.009194
# 25                0.025765             0.022544
#
# [26 rows x 25 columns]

# %%
df.describe()
# Out:
#        alpha-chars-ratio  digit-chars-ratio  upper-chars-ratio  \
# count          26.000000          26.000000          26.000000
# mean            0.788450           0.022881           0.015526
# std             0.020304           0.012491           0.006090
# min             0.754937           0.003070           0.006262
# 25%             0.771914           0.010895           0.010835
# 50%             0.786976           0.024942           0.015048
# 75%             0.807295           0.033247           0.020818
# max             0.821545           0.040644           0.025875
#
#        white-chars-ratio  number-of-words  size-of-vocabulary  \
# count          26.000000        26.000000           26.000000
# mean            0.152269       685.500000          320.500000
# std             0.005290       224.735444           75.704293
# min             0.142648       315.000000          188.000000
# 25%             0.150059       548.250000          279.750000
# 50%             0.152545       623.500000          296.000000
# 75%             0.155259       783.750000          373.750000
# max             0.162620      1411.000000          534.000000
#
#        type-token-ratio  hapax-legomena  hapax-dislegomena  mean-word-length  \
# count         26.000000       26.000000          26.000000         26.000000
# mean          42.367308      224.846154          45.653846          6.410582
# std            5.148553       50.139559          12.148884          0.217956
# min           32.929642      142.000000          24.000000          5.983278
# 25%           39.353588      198.500000          38.250000          6.322963
# 50%           43.186935      210.500000          43.500000          6.402597
# 75%           45.240932      264.750000          52.500000          6.535432
# max           57.062147      333.000000          80.000000          6.949002
#
#        ...  exclamation_mark_rate  question-mark-rate  adverbs-rate  \
# count  ...                   26.0                26.0     26.000000
# mean   ...                    0.0                 0.0      0.005749
# std    ...                    0.0                 0.0      0.002183
# min    ...                    0.0                 0.0      0.002228
# 25%    ...                    0.0                 0.0      0.004184
# 50%    ...                    0.0                 0.0      0.005537
# 75%    ...                    0.0                 0.0      0.007452
# max    ...                    0.0                 0.0      0.009954
#
#        adjectives-rate  nouns-rate  prepositions-rate  conjuctions-rate  \
# count        26.000000   26.000000          26.000000         26.000000
# mean          0.021353    0.033536           0.017049          0.007892
# std           0.002997    0.005245           0.002947          0.001430
# min           0.016281    0.024959           0.010950          0.006088
# 25%           0.018877    0.029404           0.015124          0.006983
# 50%           0.021048    0.033633           0.016547          0.007737
# 75%           0.023130    0.037983           0.018755          0.008505
# max           0.027993    0.042011           0.022995          0.012162
#
#        verb-rate  adjectivs-adverbs-rate  named-entites-count
# count  26.000000               26.000000            26.000000
# mean    0.019728                0.027102             0.013122
# std     0.003193                0.003811             0.006929
# min     0.013967                0.020091             0.002000
# 25%     0.017461                0.023802             0.006582
# 50%     0.018989                0.027368             0.013834
# 75%     0.022389                0.030037             0.019171
# max     0.025690                0.035491             0.022544
#
# [8 rows x 23 columns]

# %%
df.to_csv('Paper-features.csv')
